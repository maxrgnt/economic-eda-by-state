# %% [markdown]
# ## The grandfather of data viz - matplotlib & seaborn
# ### How to build a line chart using time series data

# %%
import pandas as pd
from pathlib import Path
import os
import numpy

# %%
# new visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# read in the data
path2data = Path.joinpath(Path.cwd().parent,'data','ufo.csv')
df = pd.read_csv(path2data)
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# check out time variable
df['Time'].describe()
# Out:
# count              80543
# unique             68901
# top       7/4/2014 22:00
# freq                  45
# Name: Time, dtype: object

# %%
df['Time'].dtype
# Out:
# dtype('O')

# %%
# convert from string to datetime format
df['newtime'] = pd.to_datetime(df['Time'])
print(df['newtime'].dtype)
# Out:
# datetime64[ns]

# %%
df[['Time','newtime']].head()
# Out:
#               Time             newtime
# 0   6/1/1930 22:00 1930-06-01 22:00:00
# 1  6/30/1930 20:00 1930-06-30 20:00:00
# 2  2/15/1931 14:00 1931-02-15 14:00:00
# 3   6/1/1931 13:00 1931-06-01 13:00:00
# 4  4/18/1933 19:00 1933-04-18 19:00:00

# %%
# create new variables
df['Date'] = df['newtime'].dt.date
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#               newtime        Date
# 0 1930-06-01 22:00:00  1930-06-01
# 1 1930-06-30 20:00:00  1930-06-30
# 2 1931-02-15 14:00:00  1931-02-15
# 3 1931-06-01 13:00:00  1931-06-01
# 4 1933-04-18 19:00:00  1933-04-18

# %%
# create a few more
df['Year'] = df['newtime'].dt.year
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#               newtime        Date  Year
# 0 1930-06-01 22:00:00  1930-06-01  1930
# 1 1930-06-30 20:00:00  1930-06-30  1930
# 2 1931-02-15 14:00:00  1931-02-15  1931
# 3 1931-06-01 13:00:00  1931-06-01  1931
# 4 1933-04-18 19:00:00  1933-04-18  1933

# %%
# create more
df['Month'] = df['newtime'].dt.month
df['Day'] = df['newtime'].dt.day
df['Hour'] = df['newtime'].dt.hour
df['Weekday'] = df['newtime'].dt.weekday
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#               newtime        Date  Year  Month  Day  Hour  Weekday
# 0 1930-06-01 22:00:00  1930-06-01  1930      6    1    22        6
# 1 1930-06-30 20:00:00  1930-06-30  1930      6   30    20        0
# 2 1931-02-15 14:00:00  1931-02-15  1931      2   15    14        6
# 3 1931-06-01 13:00:00  1931-06-01  1931      6    1    13        0
# 4 1933-04-18 19:00:00  1933-04-18  1933      4   18    19        1

# %%
# also allows date time math
# what is the extent from first to last UFO
print(df['newtime'].max())
print(df['newtime'].min())
print('difference:',df['Year'].max()-df['Year'].min())
# Out:
# 2014-09-05 05:30:00
# 1930-06-01 22:00:00
# difference: 84

# %% [markdown]
# # Create a weekday variable using .map

# %%
df['weekday_name'] = df['Weekday'].map({0:'Sunday',
                                         1:'Monday',
                                         2:'Tuesday',
                                         3:'Wednesday',
                                         4:'Thursday',
                                         5:'Friday',
                                         6:'Saturday'})

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#               newtime        Date  Year  Month  Day  Hour  Weekday  \
# 0 1930-06-01 22:00:00  1930-06-01  1930      6    1    22        6
# 1 1930-06-30 20:00:00  1930-06-30  1930      6   30    20        0
# 2 1931-02-15 14:00:00  1931-02-15  1931      2   15    14        6
# 3 1931-06-01 13:00:00  1931-06-01  1931      6    1    13        0
# 4 1933-04-18 19:00:00  1933-04-18  1933      4   18    19        1
#
#   weekday_name
# 0     Saturday
# 1       Sunday
# 2     Saturday
# 3       Sunday
# 4       Monday

# %%
df['Date'].value_counts(ascending=False).head(5)
# Out:
# 2014-07-04    258
# 2010-07-04    202
# 2012-07-04    188
# 1999-11-16    187
# 2013-07-04    177
# Name: Date, dtype: int64

# %%
# to create a linechart, we want a "counter" column
df['sightings'] = 1
df.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time  \
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
#
#               newtime        Date  Year  Month  Day  Hour  Weekday  \
# 0 1930-06-01 22:00:00  1930-06-01  1930      6    1    22        6
# 1 1930-06-30 20:00:00  1930-06-30  1930      6   30    20        0
# 2 1931-02-15 14:00:00  1931-02-15  1931      2   15    14        6
#
#   weekday_name  sightings
# 0     Saturday          1
# 1       Sunday          1
# 2     Saturday          1

# %%
# now add a group by statement to cluster data around dates
dates_df = df.groupby('Date')['sightings'].sum()
df.drop('sightings', axis = 1)
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# 13                   Keokuk             NaN           OVAL    IA
# 14                Ludington             NaN           DISK    MI
# 15              Forest Home             NaN         CIRCLE    CA
# 16              Los Angeles             NaN            NaN    CA
# 17                Hapeville             NaN            NaN    GA
# 18                   Oneida             NaN      RECTANGLE    TN
# 19               Bering Sea             RED          OTHER    AK
# 20                 Nebraska             NaN           DISK    NE
# 21                      NaN             NaN            NaN    LA
# 22                      NaN             NaN          LIGHT    LA
# 23                Owensboro             NaN      RECTANGLE    KY
# 24               Wilderness             NaN           DISK    WV
# 25                San Diego             NaN          CIGAR    CA
# 26               Wilderness             NaN           DISK    WV
# 27                   Clovis             NaN           DISK    NM
# 28               Los Alamos             NaN           DISK    NM
# 29             Ft. Duschene             NaN           DISK    UT
# ...                     ...             ...            ...   ...
# 80513            Manahawkin             NaN         CIRCLE    NJ
# 80514           New Bedford             NaN          LIGHT    MA
# 80515            Woodbridge             NaN       TRIANGLE    VA
# 80516              Glendale             NaN       CYLINDER    CA
# 80517               Laconia             NaN          CIGAR    NH
# 80518             Langhorne             NaN          OTHER    PA
# 80519            Glen Ellyn             RED         CIRCLE    IL
# 80520            Waynesburg             NaN          FLASH    PA
# 80521      Canal Winchester             NaN       TRIANGLE    OH
# 80522              Lawrence          ORANGE          LIGHT    MA
# 80523         Ellicott City             NaN          LIGHT    MD
# 80524               Olympia             RED          LIGHT    WA
# 80525             Iowa City            BLUE          LIGHT    IA
# 80526            Marshfield             NaN          LIGHT    MA
# 80527               Seattle             NaN        DIAMOND    WA
# 80528        North Royalton             RED       TRIANGLE    OH
# 80529             Deer Park             NaN          LIGHT    WA
# 80530         Glen St. Mary             NaN           DISK    FL
# 80531              Abingdon             NaN         CIRCLE    VA
# 80532              Lawrence             NaN          LIGHT    MA
# 80533             Melbourne             NaN           OVAL    IA
# 80534              Burleson             NaN          LIGHT    TX
# 80535         Elizabethtown             NaN         CIRCLE    KY
# 80536               Wyoming             RED           DISK    PA
# 80537                Neligh             NaN         CIRCLE    NE
# 80538                Neligh             NaN         CIRCLE    NE
# 80539          Uhrichsville             NaN          LIGHT    OH
# 80540                Tucson        RED BLUE            NaN    AZ
# 80541           Orland park             RED          LIGHT    IL
# 80542              Loughman             NaN          LIGHT    FL
#
#                    Time             newtime        Date  Year  Month  Day  \
# 0        6/1/1930 22:00 1930-06-01 22:00:00  1930-06-01  1930      6    1
# 1       6/30/1930 20:00 1930-06-30 20:00:00  1930-06-30  1930      6   30
# 2       2/15/1931 14:00 1931-02-15 14:00:00  1931-02-15  1931      2   15
# 3        6/1/1931 13:00 1931-06-01 13:00:00  1931-06-01  1931      6    1
# 4       4/18/1933 19:00 1933-04-18 19:00:00  1933-04-18  1933      4   18
# 5       9/15/1934 15:30 1934-09-15 15:30:00  1934-09-15  1934      9   15
# 6        6/15/1935 0:00 1935-06-15 00:00:00  1935-06-15  1935      6   15
# 7        7/15/1936 0:00 1936-07-15 00:00:00  1936-07-15  1936      7   15
# 8      10/15/1936 17:00 1936-10-15 17:00:00  1936-10-15  1936     10   15
# 9        6/15/1937 0:00 1937-06-15 00:00:00  1937-06-15  1937      6   15
# 10      8/15/1937 21:00 1937-08-15 21:00:00  1937-08-15  1937      8   15
# 11       6/1/1939 20:00 1939-06-01 20:00:00  1939-06-01  1939      6    1
# 12      6/30/1939 20:00 1939-06-30 20:00:00  1939-06-30  1939      6   30
# 13        7/7/1939 2:00 1939-07-07 02:00:00  1939-07-07  1939      7    7
# 14       6/1/1941 13:00 1941-06-01 13:00:00  1941-06-01  1941      6    1
# 15       7/2/1941 11:30 1941-07-02 11:30:00  1941-07-02  1941      7    2
# 16       2/25/1942 0:00 1942-02-25 00:00:00  1942-02-25  1942      2   25
# 17       6/1/1942 22:30 1942-06-01 22:30:00  1942-06-01  1942      6    1
# 18       7/15/1942 1:00 1942-07-15 01:00:00  1942-07-15  1942      7   15
# 19      4/30/1943 23:00 1943-04-30 23:00:00  1943-04-30  1943      4   30
# 20       6/1/1943 15:00 1943-06-01 15:00:00  1943-06-01  1943      6    1
# 21       8/15/1943 0:00 1943-08-15 00:00:00  1943-08-15  1943      8   15
# 22       8/15/1943 0:00 1943-08-15 00:00:00  1943-08-15  1943      8   15
# 23     10/15/1943 11:00 1943-10-15 11:00:00  1943-10-15  1943     10   15
# 24       1/1/1944 10:00 1944-01-01 10:00:00  1944-01-01  1944      1    1
# 25       1/1/1944 12:00 1944-01-01 12:00:00  1944-01-01  1944      1    1
# 26       1/1/1944 12:00 1944-01-01 12:00:00  1944-01-01  1944      1    1
# 27       4/2/1944 11:00 1944-04-02 11:00:00  1944-04-02  1944      4    2
# 28       6/1/1944 12:00 1944-06-01 12:00:00  1944-06-01  1944      6    1
# 29      6/30/1944 10:00 1944-06-30 10:00:00  1944-06-30  1944      6   30
# ...                 ...                 ...         ...   ...    ...  ...
# 80513     9/4/2014 8:30 2014-09-04 08:30:00  2014-09-04  2014      9    4
# 80514     9/4/2014 9:47 2014-09-04 09:47:00  2014-09-04  2014      9    4
# 80515    9/4/2014 16:30 2014-09-04 16:30:00  2014-09-04  2014      9    4
# 80516    9/4/2014 17:38 2014-09-04 17:38:00  2014-09-04  2014      9    4
# 80517    9/4/2014 19:02 2014-09-04 19:02:00  2014-09-04  2014      9    4
# 80518    9/4/2014 19:30 2014-09-04 19:30:00  2014-09-04  2014      9    4
# 80519    9/4/2014 20:20 2014-09-04 20:20:00  2014-09-04  2014      9    4
# 80520    9/4/2014 20:25 2014-09-04 20:25:00  2014-09-04  2014      9    4
# 80521    9/4/2014 20:30 2014-09-04 20:30:00  2014-09-04  2014      9    4
# 80522    9/4/2014 20:30 2014-09-04 20:30:00  2014-09-04  2014      9    4
# 80523    9/4/2014 20:45 2014-09-04 20:45:00  2014-09-04  2014      9    4
# 80524    9/4/2014 21:10 2014-09-04 21:10:00  2014-09-04  2014      9    4
# 80525    9/4/2014 21:11 2014-09-04 21:11:00  2014-09-04  2014      9    4
# 80526    9/4/2014 21:15 2014-09-04 21:15:00  2014-09-04  2014      9    4
# 80527    9/4/2014 21:15 2014-09-04 21:15:00  2014-09-04  2014      9    4
# 80528    9/4/2014 21:30 2014-09-04 21:30:00  2014-09-04  2014      9    4
# 80529    9/4/2014 22:00 2014-09-04 22:00:00  2014-09-04  2014      9    4
# 80530    9/4/2014 22:00 2014-09-04 22:00:00  2014-09-04  2014      9    4
# 80531    9/4/2014 22:05 2014-09-04 22:05:00  2014-09-04  2014      9    4
# 80532    9/4/2014 22:15 2014-09-04 22:15:00  2014-09-04  2014      9    4
# 80533    9/4/2014 22:15 2014-09-04 22:15:00  2014-09-04  2014      9    4
# 80534    9/4/2014 22:30 2014-09-04 22:30:00  2014-09-04  2014      9    4
# 80535    9/4/2014 22:30 2014-09-04 22:30:00  2014-09-04  2014      9    4
# 80536    9/4/2014 23:00 2014-09-04 23:00:00  2014-09-04  2014      9    4
# 80537    9/4/2014 23:20 2014-09-04 23:20:00  2014-09-04  2014      9    4
# 80538    9/4/2014 23:20 2014-09-04 23:20:00  2014-09-04  2014      9    4
# 80539     9/5/2014 1:14 2014-09-05 01:14:00  2014-09-05  2014      9    5
# 80540     9/5/2014 2:40 2014-09-05 02:40:00  2014-09-05  2014      9    5
# 80541     9/5/2014 3:43 2014-09-05 03:43:00  2014-09-05  2014      9    5
# 80542     9/5/2014 5:30 2014-09-05 05:30:00  2014-09-05  2014      9    5
#
#        Hour  Weekday weekday_name
# 0        22        6     Saturday
# 1        20        0       Sunday
# 2        14        6     Saturday
# 3        13        0       Sunday
# 4        19        1       Monday
# 5        15        5       Friday
# 6         0        5       Friday
# 7         0        2      Tuesday
# 8        17        3    Wednesday
# 9         0        1       Monday
# 10       21        6     Saturday
# 11       20        3    Wednesday
# 12       20        4     Thursday
# 13        2        4     Thursday
# 14       13        6     Saturday
# 15       11        2      Tuesday
# 16        0        2      Tuesday
# 17       22        0       Sunday
# 18        1        2      Tuesday
# 19       23        4     Thursday
# 20       15        1       Monday
# 21        0        6     Saturday
# 22        0        6     Saturday
# 23       11        4     Thursday
# 24       10        5       Friday
# 25       12        5       Friday
# 26       12        5       Friday
# 27       11        6     Saturday
# 28       12        3    Wednesday
# 29       10        4     Thursday
# ...     ...      ...          ...
# 80513     8        3    Wednesday
# 80514     9        3    Wednesday
# 80515    16        3    Wednesday
# 80516    17        3    Wednesday
# 80517    19        3    Wednesday
# 80518    19        3    Wednesday
# 80519    20        3    Wednesday
# 80520    20        3    Wednesday
# 80521    20        3    Wednesday
# 80522    20        3    Wednesday
# 80523    20        3    Wednesday
# 80524    21        3    Wednesday
# 80525    21        3    Wednesday
# 80526    21        3    Wednesday
# 80527    21        3    Wednesday
# 80528    21        3    Wednesday
# 80529    22        3    Wednesday
# 80530    22        3    Wednesday
# 80531    22        3    Wednesday
# 80532    22        3    Wednesday
# 80533    22        3    Wednesday
# 80534    22        3    Wednesday
# 80535    22        3    Wednesday
# 80536    23        3    Wednesday
# 80537    23        3    Wednesday
# 80538    23        3    Wednesday
# 80539     1        4     Thursday
# 80540     2        4     Thursday
# 80541     3        4     Thursday
# 80542     5        4     Thursday
#
# [80543 rows x 13 columns]

# %%
# now 'drop' the sightings variable, it's not needed
dates_df.sort_values(ascending=False).head()
# Out:
# Date
# 2014-07-04    258
# 2010-07-04    202
# 2012-07-04    188
# 1999-11-16    187
# 2013-07-04    177
# Name: sightings, dtype: int64

# %%
# conert to a dataframe
dates_df = pd.DataFrame(dates_df)
dates_df = dates_df.reset_index()
dates_df.head(5)
# dates_df.sort_values('sightings',ascending=False).head(3)
# Out:
#          Date  sightings
# 0  1930-06-01          1
# 1  1930-06-30          1
# 2  1931-02-15          1
# 3  1931-06-01          1
# 4  1933-04-18          1

# %%
df.drop('sightings',axis=1,inplace=True)

# %%
# let's merge that back into the original dataframe
df2 = pd.merge(df,dates_df, on = 'Date', how = 'left')
df2.sample(5)
# Out:
#                City Colors Reported Shape Reported State             Time  \
# 76544    Piscataway             NaN           OVAL    NJ  3/18/2014 10:10
# 33521       Bayside             NaN       TRIANGLE    NY   8/10/2005 1:00
# 40085    Bridgeport             NaN         CIRCLE    CT   5/26/2007 0:00
# 69079    Chesapeake             NaN         CIRCLE    VA  3/29/2013 21:20
# 77372  Purcellville             NaN          OTHER    VA   5/1/2014 20:30
#
#                   newtime        Date  Year  Month  Day  Hour  Weekday  \
# 76544 2014-03-18 10:10:00  2014-03-18  2014      3   18    10        1
# 33521 2005-08-10 01:00:00  2005-08-10  2005      8   10     1        2
# 40085 2007-05-26 00:00:00  2007-05-26  2007      5   26     0        5
# 69079 2013-03-29 21:20:00  2013-03-29  2013      3   29    21        4
# 77372 2014-05-01 20:30:00  2014-05-01  2014      5    1    20        3
#
#       weekday_name  sightings
# 76544       Monday         12
# 33521      Tuesday         12
# 40085       Friday         12
# 69079     Thursday         17
# 77372    Wednesday         38

# %%
# Trend over years
# !conda install -y -c anaconda seaborn=0.9.0


# import seaborn as sns
sns.set(rc={'figure.figsize':(18,6)})
sns.lineplot(x = 'Year', y = 'sightings', data = df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-f6b18addee84> in <module>()
#       5 # import seaborn as sns
#       6 sns.set(rc={'figure.figsize':(18,6)})
# ----> 7 sns.lineplot(x = 'Year', y = 'sightings', data = df2)
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'

# %%
# !conda install -y -c anaconda seaborn=0.9.0
# Out:
# Collecting package metadata (repodata.json): done
# Solving environment: \

# %%
# Trend over months
sns.lineplot(x='Month',y='sightings',data=df2);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-4caead3fde72> in <module>()
#       1 # Trend over months
# ----> 2 sns.lineplot(x='Month',y='sightings',data=df2);
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'

# %% [markdown]
# # Multiple lines on same plot

# %%
# create some new columns for specific colors
import numpy as np
# np.where
df['Colors Reported'].value_counts().head()
# Out:
# ORANGE    5216
# RED       4809
# GREEN     1897
# BLUE      1855
# YELLOW     842
# Name: Colors Reported, dtype: int64

# %%
# Create new color variables
df['Orange'] = np.where(df['Colors Reported']=='ORANGE',1,0)
df['Red'] = np.where(df['Colors Reported']=='RED',1,0)
df['Yellow'] = np.where(df['Colors Reported']=='YELLOW',1,0)
df['Green'] = np.where(df['Colors Reported']=='GREEN',1,0)

# %%
df['color'] = 'other'
df,loc[df['Colors Reported']=='ORANGE','color']='orange'
df,loc[df['Colors Reported']=='RED','color']='red'
df,loc[df['Colors Reported']=='GREEN','color']='green'

# %%
df['sighting']=1
dates = df.groupby(['Year','color'])['sighting'].sum()
dates.head(3)
